# %% [markdown]
# *1. BRING THE DATASET TO THE PYTHON ENVIRONMENT*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
iris = pd.read_excel('iris.xls')

# %% [markdown]
# *2. DISPLAY COLUMNS IN THE DATASET*

# %%
print('The columns in the dataset are as follows:\n',iris.columns)
iris
# Out:
# The columns in the dataset are as follows:
#  Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# *3. MEAN OF EACH COLUMN*

# %%
print('The mean of the each column in the dataset are as follows:\n')
iris.mean()
# Out:
# The mean of the each column in the dataset are as follows:
# <ipython-input-9-0799fd06e519>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# *4. CHECK FOR THE NULL VALUES PRESENT IN THE DATASET*

# %%
print('The total number of null values present in each column are as follows:\n')
iris.isna().sum()
# Out:
# The total numnber of null values present in each column are as follows:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# *5. VISUALIZATIONS*

# %%
import seaborn as sns
plt.bar(iris['Classification'],iris['PL'],color = 'r',width = 0.2)
plt.title('PETAL LENGTH CLASSIFICATION')
plt.ylabel('PL')
print('Below is how petal length varies among the given three species of iris flower')
# Out:
# Below is how petal length varies among the given three species of iris flower

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
sns.countplot(x=iris.SL)
plt.xticks(rotation=90)
plt.title('SEPAL LENGTH')
print('Below is shown where most values and least values of sepal length falls among the given three species of iris flower')
# Out:
# Below is shown where most values and least values of sepal length falls among the given three species of iris flower

# %%
print('Below is the value ranges of petal length,petal width,sepal length and sepal width of iris setosa species')
iris[['PL','PW','SL','SW']].head(50).plot()
plt.title('IRIS SETOSA')
# Out:
# Below is the value ranges of petal length,petal width,sepal length and sepal width of iris setosa species
# Text(0.5, 1.0, 'IRIS SETOSA')

# %%
plt.scatter(iris['SL'],iris['SW'])
plt.title('Scatterplot of Sepal length vs Sepal width')
plt.xlabel('SL')
plt.ylabel('SW')
# Out:
# Text(0, 0.5, 'SW')

# %%
sns.heatmap(data = iris.corr(),annot = True, cmap = 'RdYlGn')
# Out:
# <ipython-input-20-efcc658e3399>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data = iris.corr(),annot = True, cmap = 'RdYlGn')
# <Axes: >

# %% [markdown]
# From the heatmap, we come to know that the pairs that have a high correlation are:
#
# Petal Length and Sepal Length
#
# Sepal Length and Petal Width
#
# Petal Length and Petal Width
