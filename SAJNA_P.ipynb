# %% [markdown]
# ### 1. Load the dataset to python environment, 2.Make the 'passengerid' field as the index column.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing

# %%
data = pd.read_csv('titanic_dataset.csv',index_col = 'PassengerId')
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ### 3.. Check the basic details of the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
print(data.isna().sum())
sns.heatmap(data.isnull(),yticklabels=False,cbar=False)
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64
# <Axes: ylabel='PassengerId'>

# %% [markdown]
# ### 4. Fill in all the missing values present in all the columns in the dataset

# %%
data['Cabin'].fillna(method='bfill', inplace= True)
data['Cabin'].fillna(method='ffill', inplace= True)
data['Embarked'].fillna(method='bfill', inplace= True)
data['Age'] = data['Age'].fillna(data['Age'].median())
data.head(50)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
print(data.isna().sum())
sns.heatmap(data.isnull(),yticklabels=False,cbar=False)
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64
# <Axes: ylabel='PassengerId'>

# %% [markdown]
# ### 5. Check and handle outliers in at least 3 columns in the dataset

# %%
num_cols = ['Age', 'SibSp', 'Parch','Fare']
for i in num_cols:
    plt.figure()
    plt.boxplot(data[i]) # boxplot to detect outliers
    plt.title(i)

# %% [markdown]
# ### a) 'Sibsp',Parch ' contain natural number outliers below 10, so there is nothing unusual in it,so those outliers cannot be removed
# ### b)'Age' and 'Fare' contains a lot of outliers, so moving on to find the number and nature of outliers
# ### 'Age'

# %%
Q1 = np.percentile(data['Age'],25,method = 'midpoint')
Q2 = np.percentile(data['Age'],50,method = 'midpoint')
Q3 = np.percentile(data['Age'],75,method = 'midpoint')
IQR = Q3-Q1
low_lim = Q1 -1.5*IQR
up_lim = Q3 +1.5*IQR
outlier =[]
for x in data ["Age"]:
    if((x>up_lim)or(x<low_lim)):
        outlier.append(x)
print('Lower limit: ',low_lim,'Upper limit: ',up_lim)
outlier
# Out:
# Lower limit:  2.5 Upper limit:  54.5
# [2.0,
#  58.0,
#  55.0,
#  2.0,
#  66.0,
#  65.0,
#  0.83,
#  59.0,
#  71.0,
#  70.5,
#  2.0,
#  55.5,
#  1.0,
#  61.0,
#  1.0,
#  56.0,
#  1.0,
#  58.0,
#  2.0,
#  59.0,
#  62.0,
#  58.0,
#  63.0,
#  65.0,
#  2.0,
#  0.92,
#  61.0,
#  2.0,
#  60.0,
#  1.0,
#  1.0,
#  64.0,
#  65.0,
#  56.0,
#  0.75,
#  2.0,
#  63.0,
#  58.0,
#  55.0,
#  71.0,
#  2.0,
#  64.0,
#  62.0,
#  62.0,
#  60.0,
#  61.0,
#  57.0,
#  80.0,
#  2.0,
#  0.75,
#  56.0,
#  58.0,
#  70.0,
#  60.0,
#  60.0,
#  70.0,
#  0.67,
#  57.0,
#  1.0,
#  0.42,
#  2.0,
#  1.0,
#  62.0,
#  0.83,
#  74.0,
#  56.0]

# %% [markdown]
# ### There are some decimal values below the lower limit in the ouliers, those are set to lower limit

# %%
data['Age'] = np.where(data['Age'] < low_lim, low_lim, data['Age'])
outlier =[]
for x in data ["Age"]:
    if((x>up_lim)or(x<low_lim)):
        outlier.append(x)
outlier
# Out:
# [58.0,
#  55.0,
#  66.0,
#  65.0,
#  59.0,
#  71.0,
#  70.5,
#  55.5,
#  61.0,
#  56.0,
#  58.0,
#  59.0,
#  62.0,
#  58.0,
#  63.0,
#  65.0,
#  61.0,
#  60.0,
#  64.0,
#  65.0,
#  56.0,
#  63.0,
#  58.0,
#  55.0,
#  71.0,
#  64.0,
#  62.0,
#  62.0,
#  60.0,
#  61.0,
#  57.0,
#  80.0,
#  56.0,
#  58.0,
#  70.0,
#  60.0,
#  60.0,
#  70.0,
#  57.0,
#  62.0,
#  74.0,
#  56.0]

# %% [markdown]
# ### Since all these are valid ages,they cannot  be neglected
# ### 'Fare'

# %%
q1 = np.percentile(data['Fare'],25,method = 'midpoint')
q2 = np.percentile(data['Fare'],50,method = 'midpoint')
q3 = np.percentile(data['Fare'],75,method = 'midpoint')
IQR = q3-q1
low_lim = q1 -1.5*IQR
up_lim = q3 +1.5*IQR
outlier2 =[]
for x in data ["Fare"]:
    if((x>up_lim)or(x<low_lim)):
        outlier2.append(x)
outlier2
# Out:
# [71.2833,
#  263.0,
#  146.5208,
#  82.1708,
#  76.7292,
#  80.0,
#  83.475,
#  73.5,
#  263.0,
#  77.2875,
#  247.5208,
#  73.5,
#  77.2875,
#  79.2,
#  66.6,
#  69.55,
#  69.55,
#  146.5208,
#  69.55,
#  113.275,
#  76.2917,
#  90.0,
#  83.475,
#  90.0,
#  79.2,
#  86.5,
#  512.3292,
#  79.65,
#  153.4625,
#  135.6333,
#  77.9583,
#  78.85,
#  91.0792,
#  151.55,
#  247.5208,
#  151.55,
#  110.8833,
#  108.9,
#  83.1583,
#  262.375,
#  164.8667,
#  134.5,
#  69.55,
#  135.6333,
#  153.4625,
#  133.65,
#  66.6,
#  134.5,
#  263.0,
#  75.25,
#  69.3,
#  135.6333,
#  82.1708,
#  211.5,
#  227.525,
#  73.5,
#  120.0,
#  113.275,
#  90.0,
#  120.0,
#  263.0,
#  81.8583,
#  89.1042,
#  91.0792,
#  90.0,
#  78.2667,
#  151.55,
#  86.5,
#  108.9,
#  93.5,
#  221.7792,
#  106.425,
#  71.0,
#  106.425,
#  110.8833,
#  227.525,
#  79.65,
#  110.8833,
#  79.65,
#  79.2,
#  78.2667,
#  153.4625,
#  77.9583,
#  69.3,
#  76.7292,
#  73.5,
#  113.275,
#  133.65,
#  73.5,
#  512.3292,
#  76.7292,
# ...

# %% [markdown]
# ### As the cruise can have any fare ranges that falls in the outliers according to the classes and luxuries of the passengers, outliers cannot be removed.

# %% [markdown]
# ### 6. Do min max scaling on the feature set.

# %%
# Some irrelevant fearures are dropped inorder to scale the data

data1 = data.drop(['Name'],axis = 1,inplace= True)
data2 = data.drop(['Pclass'],axis = 1,inplace= True)
data3 = data.drop(['Ticket'],axis = 1,inplace= True)
data4 = data.drop(['Embarked'],axis = 1,inplace= True)

# %% [markdown]
# ### Encoding object columns

# %%
std = preprocessing.StandardScaler()
le = LabelEncoder()

data['Sex'] = le.fit_transform(data['Sex'])
data['Cabin'] = le.fit_transform(data['Cabin'])

# %%
minmax = preprocessing.MinMaxScaler(feature_range=(0,1))

#x = (minmax.fit_transform(data))
#x = pd.DataFrame(x)
y = data['Survived']
X = data.drop('Survived',axis=1)
x = minmax.fit_transform(X)
x = pd.DataFrame(x)

# %%
x.describe()
# Out:
#                 0           1           2           3           4           5
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.647587    0.347004    0.065376    0.063599    0.062858    0.526344
# std      0.477990    0.167139    0.137843    0.134343    0.096995    0.287483
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.251613    0.000000    0.000000    0.015440    0.280822
# 50%      1.000000    0.329032    0.000000    0.000000    0.028213    0.534247
# 75%      1.000000    0.419355    0.125000    0.000000    0.060508    0.770548
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
